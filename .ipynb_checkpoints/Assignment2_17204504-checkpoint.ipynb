# %% [markdown]
# #### Scraping and pre-processing a corpus of news article from a set of web-pages and evaluating the performance of automated classification of these articles in a supervised learning context.

# %% [markdown]
# ## Part 1
#
# ## Data Collection

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import sklearn
import nltk
import scipy
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Retrieving the monthly news URL's from the website

# %%
r  = requests.get("http://mlg.ucd.ie/modules/COMP41680/archive/index.html")

data = r.text

soup = BeautifulSoup(data, "lxml")
monthly_news = []

lists = soup.find_all('li')
    
for link in lists:
    monthly_news.append(link.find("a").get('href'))

print(monthly_news)
# Out:
# ['month-jan-2017.html', 'month-feb-2017.html', 'month-mar-2017.html', 'month-apr-2017.html', 'month-may-2017.html', 'month-jun-2017.html', 'month-jul-2017.html', 'month-aug-2017.html', 'month-sep-2017.html', 'month-oct-2017.html', 'month-nov-2017.html', 'month-dec-2017.html']

# %% [markdown]
# ### Retrieving news urls and category lables for each month

# %%
articles = {} # Creating a dictionary to store articles based on their link

for month in monthly_news:
    
    r  = requests.get("http://mlg.ucd.ie/modules/COMP41680/archive/" + month)

    data = r.text

    soup = BeautifulSoup(data, "lxml")
    
    
    news_list = soup.find('tbody').find_all('tr')

    
    for news in news_list:
        category_td = news.find("td", {"class": "category"})
        category = category_td.text.strip() #Removing the escape characters from category
                
        if (category != 'N/A'):
            news_links = news.find("td", {"class": "title"})
            news_href = news_link.find("a").get('href')
            
            article_link = "http://mlg.ucd.ie/modules/COMP41680/archive/" + news_href
            
            articles[article_link] = category
        
print(articles_links)
# Out:
# {'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-0418.html': 'technology', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-0027.html': 'business', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-0631.html': 'technology', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-2105.html': 'business', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-3300.html': 'sport', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-4187.html': 'sport', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-1974.html': 'sport', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-3666.html': 'sport', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-2629.html': 'technology', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-2415.html': 'technology', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-4210.html': 'sport', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-4789.html': 'business', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-3452.html': 'business', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-2428.html': 'technology', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-4766.html': 'technology', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-2595.html': 'technology', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-2935.html': 'business', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-0578.html': 'business', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-3023.html': 'technology', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-2356.html': 'sport', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-1023.html': 'sport', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-0641.html': 'business', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-2461.html': 'sport', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-4541.html': 'sport', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-1259.html': 'sport', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-4007.html': 'technology', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-4171.html': 'business', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-0272.html': 'technology', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-4894.html': 'sport', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-4504.html': 'business', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-1740.html': 'technology', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-2390.html': 'business', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-4471.html': 'sport', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-3978.html': 'business', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-2209.html': 'business', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-0858.html': 'business', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-3187.html': 'business', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-1282.html': 'business', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-3414.html': 'technology', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-2289.html': 'technology', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-1899.html': 'technology', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-3686.html': 'business', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-3679.html': 'business', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-1469.html': 'sport', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-4815.html': 'sport', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-1761.html': 'business', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-4519.html': 'business', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-0248.html': 'technology', 'http://mlg.ucd.ie/modules/COMP41680/archive/article-jan-1280.html': 'sport', 'http://mlg.ucd.ie/modules/COMP41680/archive/ ...
